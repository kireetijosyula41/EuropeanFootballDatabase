# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

page = "https://www.transfermarkt.us/as-saint-etienne/startseite/verein/618"
pageTree = requests.get(page, headers = headers)
pageSoup = BeautifulSoup(pageTree.content, 'html.parser')

# %%
PlayersList = []
AgeList = []
RolesList = []
PositionsList = []
NationList = []
ValuesList = []
TopScorersList = []
TopAssistersList = []
PlayerLinks = []
TeamName = []
TeamNameFinal = []
NameID = []
PlayerID = []
TeamDetails = {}

Players = pageSoup.find_all("img", {"class": "bilderrahmen-fixed lazy lazy"})
Age = pageSoup.find_all("td", {"class": "zentriert"})
Roles = pageSoup.find_all("td", {"class": ["zentriert rueckennummer bg_Torwart", "zentriert rueckennummer bg_Abwehr", 
                                           "zentriert rueckennummer bg_Mittelfeld", "zentriert rueckennummer bg_Sturm"]})
Positions = pageSoup.find_all("tr", {"class": ["odd", "even"]})
Nationality = pageSoup.find_all("td", {"class": "zentriert"})
Values = pageSoup.find_all("td", {"class": "rechts hauptlink"})
TopScorers = pageSoup.find_all("td", {"class": "zentriert tore"})
Headers = pageSoup.find_all("li", {"class": "data-header__label"})
TeamName = pageSoup.find_all("h1", {"class": "data-header__headline-wrapper--oswald"})

# %%
Players
# Out:
# [<img alt="Gautier Larsonneur" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/357047-1727720726.jpg?lm=1" src="..." title="Gautier Larsonneur"/>,
#  <img alt="Brice Maubleu" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/78047-1727720955.jpg?lm=1" src="..." title="Brice Maubleu"/>,
#  <img alt="Boubacar Fall" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/836132-1727720972.jpg?lm=1" src="..." title="Boubacar Fall"/>,
#  <img alt="Dylan Batubinsika" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/289432-1727722809.jpg?lm=1" src="..." title="Dylan Batubinsika"/>,
#  <img alt="Mickaël Nade" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/494586-1727722979.jpg?lm=1" src="..." title="Mickaël Nade"/>,
#  <img alt="Léo Pétrot" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/412829-1727723239.jpg?lm=1" src="..." title="Léo Pétrot"/>,
#  <img alt="Anthony Briançon" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/190338-1727722993.jpg?lm=1" src="..." title="Anthony Briançon"/>,
#  <img alt="Yunis Abdelhamid" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/199704-1727723225.jpg?lm=1" src="..." title="Yunis Abdelhamid"/>,
#  <img alt="Pierre Cornud" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/536156-1727723010.jpg?lm=1" src="..." title="Pierre Cornud"/>,
#  <img alt="Lucas Stassin" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/655012-1727721924.jpg?lm=1" src="..." title="Lucas Stassin"/>,
#  <img alt="Ibrahim Sissoko" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/484888-1727721906.jpg?lm=1" src="..." title="Ibrahim Sissoko"/>,
#  <img alt="Ibrahima Wadji" class="bilderrahmen-fixed lazy lazy" data-src="https://img.a.transfermarkt.technology/portrait/medium/364232-1727721772.jpg?lm=1" src="..." title="Ibrahima Wadji"/>]

# %%
for i in range(0, len(Players)):
    PlayersList.append(str(Players[i]).split('" class',1)[0].split('<img alt="',1) [1])
for i in range(1, (len (Players)*3),3):
    AgeList.append(str(Age[i]).split("(",1)[1].split(")",1)[0])
for i in range(0, len(Roles)):
    RolesList.append(str(Positions[i]).split('title="',1)[1].split('"><div')[0])
for i in range(2, (len (Players)*3),3) :
    NationList.append(str(Nationality[i]).split('title="',1)[1].split('"/',1)[0])
for i in range(0, len (Values)):
    if Values[i].text == '-':
        ValuesList.append('€0.0m')
    elif Values[i].text[-1] == 'k':
        millvalue = int(Values[i].text.strip('€').strip('k')) / 1000
        finalprice = f"€{str(millvalue)}m"
        ValuesList.append(finalprice)
    else:
        ValuesList.append(Values[i].text)
for i in range(0, len(Positions)):
    PositionsList.append(str(Positions[i].select_one('table.inline-table tr:nth-of-type(2) td').text.strip()))
for i in range(0, len(Positions)):
    pattern = r'href="(/[^"]+)"'
    playerlinks = re.findall(pattern, str(Positions[i]))
    if playerlinks[0].split('/')[1] != "profil" and len(playerlinks) >= 3:
        PlayerLinks.append(f"https://www.transfermarkt.us{playerlinks[2]}")
    else: 
        PlayerLinks.append(f"https://www.transfermarkt.us{playerlinks[0]}")
for i in range(0, len(Headers)):
    soup = BeautifulSoup(str(Headers[i]), 'html.parser')
    key = soup.find('li', class_='data-header__label').contents[0].strip(': \n')
    value = soup.find('span', class_='data-header__content').text.strip()
    TeamDetails[key] = value
    
Name = " ".join(TeamName[0].text.split())
print(Name)
                                      
TeamDetails.pop("Current transfer record")
string2 = TeamDetails['Stadium']
capacity = re.search(r'(\d{1,3}(?:\.\d{3})*) Seats', string2)
seats_number = capacity.group(1).replace('.', '')
TeamDetails['Capacity'] = seats_number
string = TeamDetails['Stadium'].split('\xa0\xa0')
TeamDetails['Stadium'] = string[0]
TeamDetails['Foreigners'] = TeamDetails['Foreigners'].split('\xa0\xa0')[0]

for i in range(0, int(TeamDetails['Squad size'])):
    TeamNameFinal.append(Name)
# Out:
# AS Saint-Étienne

# %%
TeamDetails
print(len(PlayersList), len(AgeList), len(TeamNameFinal), len(PositionsList), len(RolesList), len(NationList), len(ValuesList), len(PlayerLinks))
# Out:
# 27 27 27 27 27 27 27 27

# %%
final_dt = pd.DataFrame({"Names":PlayersList,
                     "Age":AgeList,
                     "Team": TeamNameFinal,
                     "Position":PositionsList,
                     "Roles":RolesList,
                     "Nationality":NationList,
                     "Market Value (In Millions)":ValuesList,
                     "Player Profile Link":PlayerLinks})

print(final_dt.shape)
print(final_dt)
# Out:
# (27, 8)
#                   Names Age              Team            Position       Roles  \
# 0    Gautier Larsonneur  27  AS Saint-Étienne          Goalkeeper  Goalkeeper
# 1         Brice Maubleu  35  AS Saint-Étienne          Goalkeeper  Goalkeeper
# 2         Boubacar Fall  23  AS Saint-Étienne          Goalkeeper  Goalkeeper
# 3     Dylan Batubinsika  28  AS Saint-Étienne         Centre-Back    Defender
# 4          Mickaël Nade  25  AS Saint-Étienne         Centre-Back    Defender
# 5            Léo Pétrot  27  AS Saint-Étienne         Centre-Back    Defender
# 6      Anthony Briançon  30  AS Saint-Étienne         Centre-Back    Defender
# 7      Yunis Abdelhamid  37  AS Saint-Étienne         Centre-Back    Defender
# 8         Pierre Cornud  27  AS Saint-Étienne           Left-Back    Defender
# 9           Yvann Maçon  26  AS Saint-Étienne          Right-Back    Defender
# 10        Dennis Appiah  32  AS Saint-Étienne          Right-Back    Defender
# 11         Pierre Ekwah  22  AS Saint-Étienne  Defensive Midfield    Midfield
# 12         Lamine Fomba  26  AS Saint-Étienne  Defensive Midfield    Midfield
# 13         Louis Mouton  22  AS Saint-Étienne  Defensive Midfield    Midfield
# 14    Thomas Monconduit  33  AS Saint-Étienne  Defensive Midfield    Midfield
# 15       Mathis Amougou  18  AS Saint-Étienne    Central Midfield    Midfield
# 16       Aïmen Moueffek  23  AS Saint-Étienne    Central Midfield    Midfield
# 17  Benjamin Bouchouari  23  AS Saint-Étienne    Central Midfield    Midfield
# 18      Florian Tardieu  32  AS Saint-Étienne    Central Midfield    Midfield
# 19     Augustine Boakye  24  AS Saint-Étienne  Attacking Midfield    Midfield
# 20     Igor Miladinovic  21  AS Saint-Étienne  Attacking Midfield    Midfield
# 21              Ben Old  22  AS Saint-Étienne         Left Winger      Attack
# 22  Zuriko Davitashvili  23  AS Saint-Étienne        Right Winger      Attack
# 23       Mathieu Cafaro  27  AS Saint-Étienne        Right Winger      Attack
# 24        Lucas Stassin  20  AS Saint-Étienne      Centre-Forward      Attack
# 25      Ibrahim Sissoko  29  AS Saint-Étienne      Centre-Forward      Attack
# 26       Ibrahima Wadji  29  AS Saint-Étienne      Centre-Forward      Attack
#
#     Nationality Market Value (In Millions)  \
# 0        France                     €4.00m
# 1        France                     €0.35m
# 2       Senegal                      €0.1m
# 3      DR Congo                     €2.00m
# 4        France                     €1.50m
# 5        France                     €1.00m
# 6        France                     €1.00m
# 7       Morocco                      €0.6m
# 8        France                     €1.20m
# 9        France                     €2.00m
# 10       France                     €1.00m
# 11       France                     €3.00m
# 12       France                     €1.20m
# 13       France                      €0.6m
# 14       France                      €0.4m
# 15       France                     €6.00m
# 16      Morocco                     €3.00m
# 17      Morocco                     €2.00m
# 18       France                     €1.00m
# 19        Ghana                     €3.00m
# 20       Serbia                     €3.00m
# 21  New Zealand                      €0.8m
# 22      Georgia                     €5.00m
# 16  https://www.transfermarkt.us/aimen-moueffek/pr...       aimen-moueffek
# 17  https://www.transfermarkt.us/benjamin-bouchoua...  benjamin-bouchouari
# 18  https://www.transfermarkt.us/florian-tardieu/p...      florian-tardieu
# 19  https://www.transfermarkt.us/augustine-boakye/...     augustine-boakye
# 20  https://www.transfermarkt.us/igor-miladinovic/...     igor-miladinovic
# 21  https://www.transfermarkt.us/ben-old/profil/sp...              ben-old
# 22  https://www.transfermarkt.us/zuriko-davitashvi...  zuriko-davitashvili
# 23  https://www.transfermarkt.us/mathieu-cafaro/pr...       mathieu-cafaro
# 24  https://www.transfermarkt.us/lucas-stassin/pro...        lucas-stassin
# 25  https://www.transfermarkt.us/ibrahim-sissoko/p...      ibrahim-sissoko
# 26  https://www.transfermarkt.us/ibrahima-wadji/pr...       ibrahima-wadji
#
#          ID
# 0    357047
# 1     78047
# 2    836132
# 3    289432
# 4    494586
# 5    412829
# 6    190338
# 7    199704
# 8    536156
# 9    580747
# 10   111038
# 11   538994
# 12   391376
# 13   904662
# 14   127182
# 15  1010854
# 16   484992
# 17   783094
# 18   212804
# 19   579263
# 20   729872
# 21   617021
# 22   427572
# 23   399383
# 24   655012
# 25   484888
# 26   364232

# %%
imageURL = []

# %%
reader = pd.read_csv("Football-Data/Players.csv")
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
count = 0
for line in reader['Player Profile Link'][2621:2622]: 
    page = line
    pageTree = requests.get(page, headers = headers)
    pageSoup = BeautifulSoup(pageTree.content, 'html.parser')
    image_tag = pageSoup.find('img', class_='data-header__profile-image')
    if image_tag:
        image_url = image_tag['src']
    imageURL.append(image_url)
    print("finished number:", count, image_url)
    count += 1
print(len(imageURL))
# Out:
# finished number: 0 https://img.a.transfermarkt.technology/portrait/header/364232-1727721772.jpg?lm=1
# 2622

# %%
reader['Player Image'] = imageURL

# %%
# Out:
#                     Names  Age              Team        Position       Roles  \
# 0          Robert Sánchez   27        Chelsea FC      Goalkeeper  Goalkeeper
# 1         Filip Jørgensen   22        Chelsea FC      Goalkeeper  Goalkeeper
# 2       Marcus Bettinelli   32        Chelsea FC      Goalkeeper  Goalkeeper
# 3         Lucas Bergström   22        Chelsea FC      Goalkeeper  Goalkeeper
# 4            Levi Colwill   21        Chelsea FC     Centre-Back    Defender
# ...                   ...  ...               ...             ...         ...
# 2617  Zuriko Davitashvili   23  AS Saint-Étienne    Right Winger      Attack
# 2618       Mathieu Cafaro   27  AS Saint-Étienne    Right Winger      Attack
# 2619        Lucas Stassin   20  AS Saint-Étienne  Centre-Forward      Attack
# 2620      Ibrahim Sissoko   29  AS Saint-Étienne  Centre-Forward      Attack
# 2621       Ibrahima Wadji   29  AS Saint-Étienne  Centre-Forward      Attack
#
#      Nationality Market Value (In Millions)  \
# 0          Spain                    €20.00m
# 1        Denmark                    €20.00m
# 2        England                     €1.00m
# 3        Finland                      €0.7m
# 4        England                    €50.00m
# ...          ...                        ...
# 2617     Georgia                     €5.00m
# 2618      France                     €2.50m
# 2619     Belgium                     €6.00m
# 2620        Mali                     €2.50m
# 2621     Senegal                     €1.00m
#
#                                     Player Profile Link              Name ID  \
# 0     https://www.transfermarkt.us/robert-sanchez/pr...       robert-sanchez
# 1     https://www.transfermarkt.us/filip-jorgensen/p...      filip-jorgensen
# 2     https://www.transfermarkt.us/marcus-bettinelli...    marcus-bettinelli
# 3     https://www.transfermarkt.us/lucas-bergstrom/p...      lucas-bergstrom
# 4     https://www.transfermarkt.us/levi-colwill/prof...         levi-colwill
# ...                                                 ...                  ...
# 2617  https://www.transfermarkt.us/zuriko-davitashvi...  zuriko-davitashvili
# 2618  https://www.transfermarkt.us/mathieu-cafaro/pr...       mathieu-cafaro
# 2619  https://www.transfermarkt.us/lucas-stassin/pro...        lucas-stassin
# 2620  https://www.transfermarkt.us/ibrahim-sissoko/p...      ibrahim-sissoko
# 2621  https://www.transfermarkt.us/ibrahima-wadji/pr...       ibrahima-wadji
#
#           ID          League  \
# 0     403151  Premier League
# 1     585323  Premier League
# 2     116648  Premier League
# 3     490606  Premier League
# 4     614258  Premier League
# ...      ...             ...
# 2617  427572         Ligue 1
# 2618  399383         Ligue 1
# 2619  655012         Ligue 1
# 2620  484888         Ligue 1
# 2621  364232         Ligue 1
#
#                                            Player Image
# 0     https://img.a.transfermarkt.technology/portrai...
# 1     https://img.a.transfermarkt.technology/portrai...
# 2     https://img.a.transfermarkt.technology/portrai...
# 3     https://img.a.transfermarkt.technology/portrai...
# 4     https://img.a.transfermarkt.technology/portrai...
# ...                                                 ...
# 2617  https://img.a.transfermarkt.technology/portrai...
# 2618  https://img.a.transfermarkt.technology/portrai...
# 2619  https://img.a.transfermarkt.technology/portrai...
# 2620  https://img.a.transfermarkt.technology/portrai...
# 2621  https://img.a.transfermarkt.technology/portrai...
#
# [2622 rows x 12 columns]

# %%
#import os
#downloads_folder = os.path.expanduser("~/Downloads/intermediatepython-finalproj-kireetijosyula41/Football-Data")
#file_path = os.path.join(downloads_folder, "Players_List.csv")
#reader.to_csv(file_path, index=False)
duplicates = reader['Names'].duplicated()
duplicate_rows = reader[duplicates]
print(duplicate_rows)
# Out:
#           Names  Age                 Team          Position     Roles  \
# 1010  Juan Cruz   24           CD Leganés      Right Winger    Attack
# 1101     Danilo   33          Juventus FC       Centre-Back  Defender
# 2145    Vitinha   24  Paris Saint-Germain  Central Midfield  Midfield
#
#      Nationality Market Value (In Millions)  \
# 1010       Spain                     €3.00m
# 1101      Brazil                     €7.00m
# 2145    Portugal                    €55.00m
#
#                                     Player Profile Link    Name ID      ID  \
# 1010  https://www.transfermarkt.us/juan-cruz/profil/...  juan-cruz  585700
# 1101  https://www.transfermarkt.us/danilo/profil/spi...     danilo  145707
# 2145  https://www.transfermarkt.us/vitinha/profil/sp...    vitinha  487469
#
#        League                                       Player Image
# 1010  La Liga  https://img.a.transfermarkt.technology/portrai...
# 1101  Serie A  https://img.a.transfermarkt.technology/portrai...
# 2145  Ligue 1  https://img.a.transfermarkt.technology/portrai...
